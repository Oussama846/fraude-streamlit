# %% [markdown]
# <a href="https://colab.research.google.com/github/Oussama846/fraude-streamlit/blob/main/Projet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv("creditcardfraud.csv")
df.head()
# Out:
#      <input type="file" id="files-f03b1893-ecc9-47fd-8e21-fc322443fa6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f03b1893-ecc9-47fd-8e21-fc322443fa6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

features = df.drop(columns=['Class', 'Time'])  # sauf classe et temps
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(contamination=0.001, random_state=42)
df['anomaly'] = iso.fit_predict(X_scaled)
df['anomaly'] = df['anomaly'].map({1: 0, -1: 1})  # 1 = fraude

# %%
from sklearn.cluster import KMeans

anomalies = df[df['anomaly'] == 1]
kmeans = KMeans(n_clusters=3, random_state=42)
anomalies['cluster'] = kmeans.fit_predict(anomalies[features.columns])
# Out:
# /tmp/ipython-input-5-1207250146.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anomalies['cluster'] = kmeans.fit_predict(anomalies[features.columns])
